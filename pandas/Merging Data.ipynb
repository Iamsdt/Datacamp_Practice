# %%
from glob import glob
import pandas as pd

files = glob('data/*.csv')
files
# Out:
# ['data/sub-est2016_all.csv',
#  'data/Pregnant_Women_Participating.csv',
#  'data/Food_Costs.csv',
#  'data/Children_Participating.csv',
#  'data/GOOG.csv',
#  'data/file.csv']

# %%
food = pd.read_csv(files[2])
food.head()
# Out:
#   State Agency or Indian Tribal Organization  2013-10-01 00:00:00  \
# 0                                Connecticut            2339387.0
# 1                                      Maine             981475.0
# 2                              Massachusetts            4516908.0
# 3                              New Hampshire             483172.0
# 4                                   New York           29070117.0
#
#    2013-11-01 00:00:00  2013-12-01 00:00:00  2014-01-01 00:00:00  \
# 0            2464447.0            2319323.0            2515399.0
# 1             970857.0             935511.0            1037893.0
# 2            4742321.0            4124801.0            4600864.0
# 3             468438.0             392224.0             491667.0
# 4           27552258.0           25821860.0           27627921.0
#
#    2014-02-01 00:00:00  2014-03-01 00:00:00  2014-04-01 00:00:00  \
# 0            2194009.0            2210381.0            2507437.0
# ...

# %%
child = pd.read_csv(files[3])
child.head()
# Out:
#   State Agency or Indian Tribal Organization  2013-10-01 00:00:00  \
# 0                                Connecticut              29609.0
# 1                                      Maine              13150.0
# 2                              Massachusetts              62801.0
# 3                              New Hampshire               7813.0
# 4                                   New York             273263.0
#
#    2013-11-01 00:00:00  2013-12-01 00:00:00  2014-01-01 00:00:00  \
# 0              28435.0              27719.0              28180.0
# 1              12777.0              12458.0              12430.0
# 2              66409.0              59556.0              61794.0
# 3               7609.0               7512.0               7556.0
# 4             267664.0             262113.0             259260.0
#
#    2014-02-01 00:00:00  2014-03-01 00:00:00  2014-04-01 00:00:00  \
# 0              26794.0              27475.0              27475.0
# ...

# %%
child.shape
# Out:
# (92, 14)

# %%
child.slice_shift()
# Out:
#    State Agency or Indian Tribal Organization  2013-10-01 00:00:00  \
# 1                                 Connecticut              29609.0
# 2                                       Maine              13150.0
# 3                               Massachusetts              62801.0
# 4                               New Hampshire               7813.0
# 5                                    New York             273263.0
# ..                                        ...                  ...
# 87                                     Oregon              58291.0
# 88                                 Washington             107422.0
# 89                          Northern Marianas               2608.0
# 90                   Inter-Tribal Council, AZ               5279.0
# 91                          Navajo Nation, AZ               5750.0
#
#     2013-11-01 00:00:00  2013-12-01 00:00:00  2014-01-01 00:00:00  \
# 1               28435.0              27719.0              28180.0
# ...

# %%
child.resample()
